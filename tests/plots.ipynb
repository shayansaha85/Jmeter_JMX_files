# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("hps.csv")
col1 = "Elapsed time"
col2 = "Server Hits per Second"

x = list(df[col1])
y = list(df[col2])

plt.xlabel(col1)
plt.ylabel(col2)

plt.figure(figsize=(20,10))
plt.plot(x,y,linewidth=3)
